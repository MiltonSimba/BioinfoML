# %% [markdown]
# # Python for Data Science - Course for beginners
# ## Introduction to the Course
#
# ### Focus
#
# - Problem Solving
#
# - Why Python
#
# - Python (Zero to Hero)
#
# - Data Science

# %% [markdown]
# ### Problem Solving
#
# - Python is very easier and quicker to use.
#
# - An algorithm is a step bystep process of how to do something.
#
# - We use pseudocode to solve problems.
#
# - Pseudocode  are arranged steps of algorithm in language which is very related to code but still in simple English as shown below:
#
#
# ** BEGIN **
#
# > input hours
#
# > input rate
#
# > pay = hours * rate
#
# > print pay
#
# ** END **
#
# - Flowcharts can also be used instead of Pseudocode to structure how the intended program should behave.
#  > - HOwever, conversion of FLowcharts to real code proves to be tedious compared to Pseudocode because Pseudocode is almost real code.

# %% [markdown]
# ### Algorithm to make Tea Example:
#
# #### Pseudocode
#
# '''
#
#  PROGRAM make tea
#
#  put teabag in cup
#
#  WHILE (water not boiled)
#  > boil water
#
#  ENDWHILE
#
#  pour water in cup
#
#
#  WHILE (sugar needed)
#  > add sugar
#
#  ENDWHILE
#
#
#  WHILE(milk needed)
#  > add milk
#
#  ENDWHILE
#
#  WHILE (need to stir)
#  > stir tea
#
#  ENDWHILE
#
#
#  Server and finish
#
#  '''
#
# - We're not going to draw a Flowchart.
#
# - THe Pseudocode above is not language-specific, anyone with knowledge of any programming language can wirte the Pseudocode above in their language of expertise.

# %% [markdown]
# - Lets say you're given a list of numbers (L)
#
# > L = [[23,-4,0,73,-10,13]]
#
# #### Search Minimum
#
# '''
#
# searchMinFromList(L,n)
# > minValue = L[[1]]
#
# > counter = 2
#
# > while (counter <= n)
#
# >      v = L[counter]
#
# >      if (v < minValue)
#
# >                  minValue
#
# >      else
#
# >                  pass
#
# >      endIF
#
# >      counter = counter + 1
#
# >  endWhile
#
# > return minValue
#
# endSearchMinFromList
#
# '''
#
# - n = number of elements

# %% [markdown]
# ### Selection Sort
#
# - the list is first sorted
#
# '''
#
# sortList(L,n)
#
# > L2 = []
#
# > counter = 1
#
# > while (counter <=n)
#
# >        min, idx = searchMinFromList (L,n)
#
# >        insert in L2 = min
#
# >        delete L[idx]
#
# >        n = n - 1
#
# > endWhile
#
# > return L2
#
# endSortList
#
# '''

# %% [markdown]
# ### Problem Solving using Python
#
# - the above pseudocode when put in Python code looks like this:
#
# - adding equations:
# $ x^2 + x + 1$

# %%
def searchMinFromList(L,n):
    minValue = L[0]       # 0 = index
    idx = 0
    counter = 1
    while (counter<n):
        v = L[counter]
        if (v<minValue):
            minValue = v
            idx = counter
        else:
            pass
        counter +=1  
    return minValue,idx

# %%
L = [13,45,76,89,98,23]
print (L.sort())
# Out:
# None

# %% [markdown]
# ### Why Python?
#
# 1. It is very easy with a lot of functions and packages
# 2. It can be used in many ways.
# 3. Beginner Friendly, almost close to human language.
# 4. Most popular in Machine Learning.
# 5. Versatile and flexible.
# 6. Most mature package libraries around which are very useful in Data Science.
# 7. Free and Open Source so anyone can contribute to building of packages.

# %% [markdown]
# What is an IDE?
#
# - When using a text editor you can write your code and test it in the terminal but in many cases this can become an exhausting task so notebooks can give one in all code writing + code execution.
#
# - Examples of Notebooks/IDEs include:
#
#
#
#  > 1. Jupyter Notebook - Easier to use and can do all your code writing and execution in the same Notebook
#
#  > 2. PyCharm - common for its key-binding, proprietary and not open-source.
#
#  > 3. Spyder - comes installed with Anaconda, its very similar to MatLab useful for Data Science and ENgineering and comes installed with DS libraries like Numpy, SciPy, Pandas and Matplotlib
#
#  > 4. Canopy - popular for its code completion
#
#  > 5. VIM
#
#  > 6. ATOM

# %%
Time 1:53:36
